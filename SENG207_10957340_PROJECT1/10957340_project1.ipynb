# %% [markdown]
# NAME: OWUSU MICHELLE

# %% [markdown]
# ID: 10957340

# %% [markdown]
# DEPARTMENT: COMPUTER ENGINEERING

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv(
'data.csv')

# %% [markdown]
# The Data at a glance:
# The dataset's first five rows are displayed below.

# %%
 data.head()
# Out:
#    ID  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0   1            7.4              0.70         0.00             1.9
# 1   2            7.8              0.88         0.00             2.6
# 2   3            7.8              0.76         0.04             2.3
# 3   4           11.2              0.28         0.56             1.9
# 4   5            7.4              0.70         0.00             1.9
#
#    chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# 0      0.076                 11.0                  34.0   0.9978  3.51
# 1      0.098                 25.0                  67.0   0.9968  3.20
# 2      0.092                 15.0                  54.0   0.9970   NaN
# 3      0.075                 17.0                  60.0   0.9980  3.16
# 4      0.076                 11.0                  34.0   0.9978  3.51
#
#    sulphates  alcohol  quality
# 0       0.56      9.4      5.0
# 1       0.68      9.8      5.0
# 2       0.65      9.8      5.0
# ...

# %%
data.shape
(1601, 13)
# Out:
# (1601, 13)

# %% [markdown]
# Getting rid of null values:
# The rows in the data displayed below have null values.

# %%
nan_rows = data[data.isnull().T.any().T]
nan_rows
# Out:
#         ID  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 2        3            7.8             0.760         0.04             2.3
# 10      11            6.7             0.580         0.08             1.8
# 23      24            8.5             0.490          NaN             2.3
# 179    180            8.8             0.610         0.14             2.4
# 581    582           12.3             0.500         0.49             2.2
# 1113  1114            8.9             0.240         0.39             1.6
# 1231  1232            7.8             0.815         0.01             2.6
# 1584  1585            6.2             0.460         0.29             2.1
# 1585  1586            6.7             0.320         0.44             2.4
# 1595  1596            NaN             0.600         0.08             2.0
#
#       chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# 2         0.092                 15.0                  54.0  0.99700   NaN
# ...

# %% [markdown]
# The duplicate rows are displayed in the data below.
# There are no duplicate rows, as can be seen.

# %%
duplicate_rows = data[data.duplicated()]
duplicate_rows
# Out:
# Empty DataFrame
# Columns: [ID, fixed acidity, volatile acidity, citric acid, residual sugar, chlorides, free sulfur dioxide, total sulfur dioxide, density, pH, sulphates, alcohol, quality]
# Index: []

# %%
data = data.dropna()
data
# Out:
#         ID  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0        1            7.4             0.700         0.00             1.9
# 1        2            7.8             0.880         0.00             2.6
# 3        4           11.2             0.280         0.56             1.9
# 4        5            7.4             0.700         0.00             1.9
# 5        6            7.4             0.660         0.00             1.8
# ...    ...            ...               ...          ...             ...
# 1596  1597            5.9             0.550         0.10             2.2
# 1597  1598            6.3             0.510         0.13             2.3
# 1598  1599            5.9             0.645         0.12             2.0
# 1599  1600            6.0             0.310         0.47             3.6
# 1600  1601            7.2             0.390         0.44             2.6
#
#       chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# ...

# %%
nan_rows = data[data.isnull().T.any().T]
nan_rows
# Out:
# Empty DataFrame
# Columns: [ID, fixed acidity, volatile acidity, citric acid, residual sugar, chlorides, free sulfur dioxide, total sulfur dioxide, density, pH, sulphates, alcohol, quality]
# Index: []

# %% [markdown]
# Because we are aware that there is no output, the null values have been eliminated.
# Because I lacked sufficient data to input or fill in the missing values, I decided to completely remove the null values using the dropna() method. Eliminating the null values will also guarantee that accurate and complete data are used for data analysis.
# Displaying overall dataset statistical inferences:

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1591 entries, 0 to 1600
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   ID                    1591 non-null   int64
#  1   fixed acidity         1591 non-null   float64
#  2   volatile acidity      1591 non-null   float64
#  3   citric acid           1591 non-null   float64
#  4   residual sugar        1591 non-null   float64
#  5   chlorides             1591 non-null   float64
#  6   free sulfur dioxide   1591 non-null   float64
#  7   total sulfur dioxide  1591 non-null   float64
#  8   density               1591 non-null   float64
#  9   pH                    1591 non-null   float64
#  10  sulphates             1591 non-null   float64
#  11  alcohol               1591 non-null   float64
#  12  quality               1591 non-null   float64
# dtypes: float64(12), int64(1)
# memory usage: 174.0 KB

# %% [markdown]
# The above only gives the basic overview of the complete dataset. It displays the dataset's column names, data types for the values in each field, and the total number of non-null values in the dataset. Using the "describe()" technique, I will provide further statistical characteristics of the complete dataset below.

# %%
data.describe()
# Out:
#                 ID  fixed acidity  volatile acidity  citric acid  \
# count  1591.000000    1591.000000       1591.000000  1591.000000
# mean    801.060968       8.320616          0.527681     0.271477
# std     460.740942       1.740134          0.179045     0.194807
# min       1.000000       4.600000          0.120000     0.000000
# 25%     402.500000       7.100000          0.390000     0.090000
# 50%     801.000000       7.900000          0.520000     0.260000
# 75%    1199.500000       9.200000          0.640000     0.420000
# max    1601.000000      15.900000          1.580000     1.000000
#
#        residual sugar    chlorides  free sulfur dioxide  total sulfur dioxide  \
# count     1591.000000  1591.000000          1591.000000           1591.000000
# mean         2.540761     0.087500            15.861722             46.498429
# std          1.413076     0.047175            10.429385             32.998659
# ...

# %% [markdown]
# A statistical breakdown of the entire dataset is shown in the information above. For each column in the dataset, it shows the count value, minimum value, maximum value, standard deviation, mean value, and the 25, 50, and 70% percentiles. For instance, the aforementioned data shows that the greatest residual sugar record is 5000 and the mean volatile acidity is 0.527681.

# %%
data.plot()
# Out:
# <Axes: >

# %% [markdown]
# Showing statistical inference to individual columns in dataset:
# Fixed acidity:

# %%
data['fixed acidity'].describe()
# Out:
# count    1591.000000
# mean        8.320616
# std         1.740134
# min         4.600000
# 25%         7.100000
# 50%         7.900000
# 75%         9.200000
# max        15.900000
# Name: fixed acidity, dtype: float64

# %%
plt.hist(data['fixed acidity'])
mean_val= data['fixed acidity'].mean()
median_val = data['fixed acidity'].median()
plt.axvline(mean_val, color='b', linestyle='--', label='Mean')
plt.axvline(median_val, color='r', linestyle='-.', label='Median')
plt.xlabel('fixed acidity')
plt.ylabel('frequency')
plt.title('Distribution of fixed acidity')
plt.legend()

# %% [markdown]
# Volatile Acidity:

# %%
data['volatile acidity']. describe()
plt.hist(data['volatile acidity'], histtype= 'bar',color= 'red', edgecolor ='violet')
mean_val= data['volatile acidity'].mean()
median_val = data['volatile acidity'].median()
plt.axvline(mean_val, color='b', linestyle='--', label='Mean')
plt.axvline(median_val, color='y', linestyle='-.', label='Median')
plt.xlabel('volatile acidity')
plt.ylabel('frequency')
plt.title('Distribution of volatile acidity')
plt.legend()

# %% [markdown]
# Citric acid:

# %%
data['citric acid'].describe()
# Out:
# count    1591.000000
# mean        0.271477
# std         0.194807
# min         0.000000
# 25%         0.090000
# 50%         0.260000
# 75%         0.420000
# max         1.000000
# Name: citric acid, dtype: float64

# %%
plt.hist(data['citric acid'], histtype= 'bar',color= 'yellow', edgecolor ='black')
mean_val= data['citric acid'].mean()
median_val = data['citric acid'].median()
plt.axvline(mean_val, color='b', linestyle='--', label='Mean')
plt.axvline(median_val, color='r', linestyle='-.', label='Median')
plt.xlabel('citric acid')
plt.ylabel('frequency')
plt.title('Distribution of citric acid')
plt.legend()

# %% [markdown]
# Residual sugar:

# %%
 data['residual sugar'].describe()
# Out:
# count    1591.000000
# mean        2.540761
# std         1.413076
# min         0.900000
# 25%         1.900000
# 50%         2.200000
# 75%         2.600000
# max        15.500000
# Name: residual sugar, dtype: float64

# %%
plt.hist(data['residual sugar'], histtype= 'bar',color= 'blue', edgecolor ='black')
mean_val= data['residual sugar'].mean()
median_val = data['residual sugar'].median()
plt.axvline(mean_val, color='y', linestyle='--', label='Mean')
plt.axvline(median_val, color='r', linestyle='-.', label='Median')
plt.xlabel('residual sugar')
plt.ylabel('frequency')
plt.title('Distribution of residual sugar')
plt.legend()

# %% [markdown]
# Chlorides:

# %%
data['chlorides'].describe()
# Out:
# count    1591.000000
# mean        0.087500
# std         0.047175
# min         0.012000
# 25%         0.070000
# 50%         0.079000
# 75%         0.090000
# max         0.611000
# Name: chlorides, dtype: float64

# %%
plt.hist(data['chlorides'], histtype= 'bar',color= 'red', edgecolor ='black')
mean_val= data['chlorides'].mean()
median_val = data['chlorides'].median()
plt.axvline(mean_val, color='y', linestyle='--', label='Mean')
plt.axvline(median_val, color='b', linestyle='-.', label='Median')
plt.xlabel('chlorides')
plt.ylabel('frequency')
plt.title('Distribution of chlorides')
plt.legend()

# %% [markdown]
# Free sulfur dioxide:

# %%
data['free sulfur dioxide'].describe()
# Out:
# count    1591.000000
# mean       15.861722
# std        10.429385
# min         1.000000
# 25%         7.000000
# 50%        14.000000
# 75%        21.000000
# max        72.000000
# Name: free sulfur dioxide, dtype: float64

# %%
plt.hist(data['free sulfur dioxide'], histtype= 'bar',color= 'brown', edgecolor ='white')
mean_val= data['free sulfur dioxide'].mean()
median_val = data['free sulfur dioxide'].median()
plt.axvline(mean_val, color='b', linestyle='--', label='Mean')
plt.axvline(median_val, color='g', linestyle='-.', label='Median')
plt.xlabel('free sulfur dioxide')
plt.ylabel('frequency')
plt.title('Distribution of free sulfur dioxide')
# Out:
# Text(0.5, 1.0, 'Distribution of free sulfur dioxide')

# %% [markdown]
# Total sulfur dioxide:

# %%
data['total sulfur dioxide'].describe()
# Out:
# count    1591.000000
# mean       46.498429
# std        32.998659
# min         6.000000
# 25%        22.000000
# 50%        38.000000
# 75%        62.000000
# max       289.000000
# Name: total sulfur dioxide, dtype: float64

# %%
plt.hist(data['total sulfur dioxide'], histtype= 'bar',color= 'teal', edgecolor ='black')
mean_val= data['total sulfur dioxide'].mean()
median_val = data['total sulfur dioxide'].median()
plt.axvline(mean_val, color='r', linestyle='-.', label='Mean')
plt.axvline(median_val, color='g', linestyle='-.', label='Median')
plt.xlabel('total sulfur dioxide')
plt.ylabel('frequency')
plt.title('total sulfur dioxide')
plt.legend()

# %% [markdown]
# Density:

# %%
data['density'].describe()
# Out:
# count    1591.000000
# mean        0.996747
# std         0.001889
# min         0.990070
# 25%         0.995600
# 50%         0.996750
# 75%         0.997845
# max         1.003690
# Name: density, dtype: float64

# %%
plt.hist(data['density'], histtype= 'bar',color= 'yellow', edgecolor ='brown')
mean_val= data['density'].mean()
median_val = data['density'].median()
plt.axvline(mean_val, color='b', linestyle='--', label='Mean')
plt.axvline(median_val, color='r', linestyle='-.', label='Median')
plt.xlabel('density')
plt.ylabel('frequency')
plt.title('density')
plt.legend()

# %% [markdown]
#  PH:

# %%
 data['pH'].describe()
# Out:
# count    1591.000000
# mean        3.311358
# std         0.154548
# min         2.740000
# 25%         3.210000
# 50%         3.310000
# 75%         3.400000
# max         4.010000
# Name: pH, dtype: float64

# %%
data['pH'].plot()
# Out:
# <Axes: >

# %% [markdown]
# Sulphates:

# %%
data['sulphates'].describe()
# Out:
# count    1591.000000
# mean        0.658611
# std         0.169786
# min         0.330000
# 25%         0.550000
# 50%         0.620000
# 75%         0.730000
# max         2.000000
# Name: sulphates, dtype: float64

# %%
plt.hist(data['sulphates'], histtype= 'step',color= 'pink', edgecolor ='black')
mean_val= data['sulphates'].mean()
median_val = data['sulphates'].median()
plt.axvline(mean_val, color='y', linestyle='--', label='Mean')
plt.axvline(median_val, color='b', linestyle='-.', label='Median')
plt.xlabel('sulphates')
plt.ylabel('frequency')
plt.title('distribution of sulphates')
plt.legend()

# %% [markdown]
# Alcohol:

# %%
data['alcohol'].describe()
# Out:
# count    1591.000000
# mean       10.426053
# std         1.066706
# min         8.400000
# 25%         9.500000
# 50%        10.200000
# 75%        11.100000
# max        14.900000
# Name: alcohol, dtype: float64

# %%
plt.hist(data['alcohol'].value_counts(), histtype= 'barstacked',color= 'violet', edgecolor ='white')
mean_val= data['alcohol'].mean()
median_val = data['alcohol'].median()
plt.axvline(mean_val, color='r', linestyle='--', label='Mean')
plt.axvline(median_val, color='b', linestyle='-.', label='Median')
plt.xlabel('alcohol')
plt.ylabel('frequency')
plt.title('alcohol')
plt.legend()

# %% [markdown]
# Quality:

# %%
data['quality'].describe()
# Out:
# count    1591.000000
# mean        5.637964
# std         0.807772
# min         3.000000
# 25%         5.000000
# 50%         6.000000
# 75%         6.000000
# max         8.000000
# Name: quality, dtype: float64

# %%
data['quality'].value_counts().plot(kind= 'pie', figsize=(6,6))
# Out:
# <Axes: ylabel='quality'>

# %% [markdown]
# Showing hidden statistical inferences:

# %%
data.plot(kind='scatter', x= 'fixed acidity', y= 'citric acid', figsize=(6,6))
# Out:
# <Axes: xlabel='fixed acidity', ylabel='citric acid'>

# %% [markdown]
# Shown below is a scatter diagram to show the relation or correlation between the free sulfur dioxide and total sulphur dioxide columns.

# %%
data.plot(kind='scatter', x= 'free sulfur dioxide', y= 'total sulfur dioxide', figsize=(6,6))
# Out:
# <Axes: xlabel='free sulfur dioxide', ylabel='total sulfur dioxide'>

# %% [markdown]
# Showing Data correlation among columns:
#
# This can easily be done using the 'corr()' method.
# ##### Below is a representsation and graph of all the correlations between all the columns

# %%
corr = data.corr()
corr
# Out:
#                             ID  fixed acidity  volatile acidity  citric acid  \
# ID                    1.000000      -0.268371         -0.006833    -0.156712
# fixed acidity        -0.268371       1.000000         -0.256737     0.672306
# volatile acidity     -0.006833      -0.256737          1.000000    -0.551511
# citric acid          -0.156712       0.672306         -0.551511     1.000000
# residual sugar       -0.031780       0.114839          0.001336     0.143731
# chlorides            -0.119930       0.093857          0.061202     0.204294
# free sulfur dioxide   0.085616      -0.150261         -0.014598    -0.057619
# total sulfur dioxide -0.115795      -0.110992          0.074132     0.038593
# density              -0.368878       0.666876          0.022504     0.364181
# pH                    0.133390      -0.683788          0.234251    -0.543230
# sulphates            -0.127397       0.184937         -0.261872     0.313530
# ...

# %% [markdown]
# Graph:

# %%
fig= plt.figure(figsize= (8,8))
plt.matshow(corr, cmap= 'RdBu', fignum= fig.number)
plt.xticks(range(len(corr.columns)), corr.columns, rotation='vertical');
plt.yticks(range(len(corr.columns)), corr.columns);

# %% [markdown]
# The correlation between each column in the dataset is shown in the graph above. Correlations are displayed with the strongest in blue and the weakest in red. Which columns are closely connected and which ones are not can be deduced from the graph.
